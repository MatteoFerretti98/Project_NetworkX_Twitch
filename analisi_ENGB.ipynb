# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import random
import seaborn as sns

# %%
edges = []
with open("twitch\ENGB\musae_ENGB_edges.csv", "r") as f:
    for line in f:
        s = line.strip()
        a, b = s.split(',')
        edges.append((int(a),int(b)))

# %%
graph = nx.Graph()
graph.add_edges_from(edges)
pos = nx.spring_layout(graph)

# %%
print("NODES: ", len(graph.nodes))
print("EDGES: ", len(graph.edges))
# Out:
# NODES:  7126
# EDGES:  35324

# %%
plt.figure(figsize=(12,8))
nx.draw(graph, pos)
plt.show()

# %%
degree = nx.degree_centrality(graph)
plt.figure(figsize=(15,10))
sns.distplot(list(degree.values()), kde=False)
# Out:
# C:\Users\simod\AppData\Local\Temp\ipykernel_14280\1139682489.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(list(degree.values()), kde=False)
# <AxesSubplot:>

# %%
def draw(G, pos, measures, measure_name):
    
    nodes = nx.draw_networkx_nodes(G, pos, node_size=250, cmap=plt.cm.plasma, 
                                   node_color=list(measures.values()),
                                   nodelist=measures.keys())
    nodes.set_norm(mcolors.SymLogNorm(linthresh=0.01, linscale=1))
    
    # labels = nx.draw_networkx_labels(G, pos)
    edges = nx.draw_networkx_edges(G, pos)

    plt.title(measure_name)
    plt.colorbar(nodes)
    plt.axis('off')
    plt.show()

# %%
plt.figure(figsize=(12,12))
pos = nx.spring_layout(graph)
draw(graph, pos, degree, 'Degree Centrality')

# %%
plt.figure(figsize=(12,12))
pos = nx.spiral_layout(graph)
draw(graph, pos, degree, 'Degree Centrality')

# %%
bet = nx.betweenness_centrality(graph)
plt.figure(figsize=(15,10))
sns.distplot(list(bet.values()), kde=False)
# Out:
# C:\Users\simod\AppData\Local\Temp\ipykernel_14280\4250561492.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(list(bet.values()), kde=False)
# <AxesSubplot:>
